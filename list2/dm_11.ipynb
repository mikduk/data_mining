# %%
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import OLSInfluence
import seaborn as sns
from patsy import dmatrices, dmatrix
from sklearn import metrics
import seaborn as sns
from scipy import stats
from sklearn.metrics import accuracy_score

# %%
# [From lab3.ipynb]
def get_model(model_formula, df):
    
    # Split the data into
    mask = np.random.rand(len(df)) < 0.8
    train = df[mask]
    valid = df[~mask]
 
    # Prepare the data
    y_train, X_train = dmatrices(model_formula, data=train, return_type='dataframe')   
    y_valid, X_valid = dmatrices(model_formula, data=valid, return_type='dataframe')

    # Define a model [linear regression]
    model = sm.OLS(y_train, X_train) 
    result = model.fit()

    # print("Training accuracy: ", accuracy_score(y_true=y_train, y_pred=model.predict(X_train)))
    # print("Validation accuracy: ", accuracy_score(y_true=y_valid, y_pred=model.predict(X_valid)))


    return result

# %%
df = pd.read_csv("data/Auto.csv")

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %% [markdown]
# ***year*** treated as a continuous variable

# %%
get_model("mpg ~ year", df).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.354
# Model:                            OLS   Adj. R-squared:                  0.352
# Method:                 Least Squares   F-statistic:                     181.2
# Date:                Tue, 13 Dec 2022   Prob (F-statistic):           3.08e-33
# Time:                        15:42:05   Log-Likelihood:                -1088.0
# No. Observations:                 333   AIC:                             2180.
# Df Residuals:                     331   BIC:                             2188.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -73.1354      7.198    -10.160      0.000     -87.296     -58.975
# year           1.2718      0.094     13.460      0.000       1.086       1.458
# ==============================================================================
# Omnibus:                       15.608   Durbin-Watson:                   0.869
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               12.689
# Skew:                           0.391   Prob(JB):                      0.00176
# Kurtosis:                       2.448   Cond. No.                     1.57e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.57e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ***year*** treated as a categorical variable

# %%
get_model("mpg ~ year", df.astype({ "year": "category" })).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.427
# Model:                            OLS   Adj. R-squared:                  0.405
# Method:                 Least Squares   F-statistic:                     19.33
# Date:                Tue, 13 Dec 2022   Prob (F-statistic):           2.89e-31
# Time:                        15:42:05   Log-Likelihood:                -1034.2
# No. Observations:                 324   AIC:                             2094.
# Df Residuals:                     311   BIC:                             2144.
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     18.0000      1.253     14.362      0.000      15.534      20.466
# year[T.71]     3.4800      1.737      2.004      0.046       0.063       6.897
# year[T.72]     0.5833      1.754      0.333      0.740      -2.868       4.034
# year[T.73]    -0.2812      1.643     -0.171      0.864      -3.514       2.952
# year[T.74]     4.2632      1.863      2.288      0.023       0.597       7.930
# year[T.75]     2.4091      1.792      1.344      0.180      -1.118       5.936
# year[T.76]     4.0345      1.678      2.404      0.017       0.732       7.337
# year[T.77]     5.1304      1.772      2.895      0.004       1.643       8.618
# year[T.78]     6.2452      1.654      3.775      0.000       2.990       9.500
# year[T.79]     6.3042      1.754      3.594      0.000       2.853       9.755
# year[T.80]    15.9391      1.772      8.993      0.000      12.452      19.427
# year[T.81]    12.5292      1.754      7.144      0.000       9.078      15.980
# year[T.82]    14.2400      1.737      8.200      0.000      10.823      17.657
# ==============================================================================
# Omnibus:                       18.130   Durbin-Watson:                   0.897
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               12.626
# Skew:                           0.364   Prob(JB):                      0.00181
# Kurtosis:                       2.363   Cond. No.                         14.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
